# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print('標題: ' + d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find(class_='article-meta-value').text)
        print('時間: ' + soup.find(class_='date').text)
    except:
        continue
# Out:
# 標題: [新聞] Tatum:會努力幫助球隊贏球，自己也想入選
# 作者: Muma5566 (木馬56)
# 時間: 12/11
# 標題: [花邊] Nelson談論當年Howard在魔術的"魔獸人生"
# 作者: TheBatman (蝙蝠俠)
# 時間: 12/11
# 標題: [新聞] 卡特第1500場出賽 史上第5人
# 作者: LinBaoYan (負酬者聯盟)
# 時間: 12/11
# 標題: [花邊] 厄文持續缺賽 錯失激勵獎金12.5萬美元
# 作者: thnlkj0665 (灰色地帶)
# 時間: 12/11
# 標題: [花邊] 當湖人主場播放歌手Lizzo歌曲時，本人在場邊直接表演露臀舞
# 作者: kairiyu (E N O U G H  is  enough)
# 時間: 12/11
# 標題: [花邊]J.J. Culver 砍下100分
# 作者: innocent8675 (坤溪戴維斯)
# 時間: 12/11
# 標題: [花邊] KD重申了自己想要擁有一支NBA球隊的願望
# 作者: NSYSUheng (Madara)
# 時間: 12/11
# 標題: Re: [花邊] Jimmy Butler的instagram貼文
# 作者: tmac4ever ()
# 時間: 12/11
# 標題: [新聞] 三分砲火猛烈 伯坦斯：籃框實在太寬了
# 作者: Israfil (贖罪聖音)
# 時間: 12/11
# 標題: [情報] New Balance 為Kawhi架設看板感謝多倫多
# 作者: thnlkj0665 (灰色地帶)
# 時間: 12/11
# 標題: [花邊] Tacko Fall：KG是傳奇，見到他對我意義
# 作者: lovea (lovea)
# 時間: 12/11
# 標題: (已被Vedan刪除) <qq326>1-1 1-2
# 標題: [討論] 08年京奧男籃的西班牙很謎嗎?
# 作者: Darren2012 (達倫)
# 時間: 12/11
# 標題: (本文已被刪除) [VeryGoodBoy]
# 標題: [討論] LBJ在投三分球之前的準備動作
# 作者: pneumo (超☆冒險蓋)
# 時間: 12/11
# 標題: [花邊] 全能後衛！Ish Smith在暫停時幫忙拖地
# 作者: whoAU (你是誰？)
# 時間: 12/11
# 標題: [花邊] 前賽爾提克球員因未尊重中國國歌遭罰款
# 作者: LinBaoYan (負酬者聯盟)
# 時間: 12/11
# 標題: [花邊] 舞王賽後發聲：跟隨我
# 作者: s27052705 (小飽)
# 時間: 12/11
# 標題: [討論] 哈登的後撤三分是現今最難被防守的嗎
# 作者: ghost069 (阿鬼)
# 時間: 12/11
# 標題: [公告] 板規v6.6
# 標題: [公告] 樂透取消及未來不再開啟樂透
# 作者: Vedan (味丹)
# 時間: 12/11
# 標題: [公告] 版主上任相關事項
# 作者: qazwsx879345 (Rajon Rondo)
# 時間: 12/11
# 標題: [情報] SEASON Schedule 賽程 December 19–20
# 作者: JerroLi (銀色小刀)
# 時間: 12/11
# 標題: [公告]是否禁止basketball top 5文章投票開始
# 作者: dragon803 (好想去露營啊~)
# 時間: 12/11

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
page = 1
url = 'https://www.ptt.cc/bbs/NBA/index'+str(page)+'.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print('標題: ' + d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find(class_='article-meta-value').text)
        print('時間: ' + soup.find(class_='date').text)
    except:
        continue
# Out:
# 標題: [轉錄]Lyotard 對於太陽板討論串的結論
# 作者: Price (Price)
# 時間:  5/16
# 標題: [公告] 請停止一切關於本次活動的發言
# 作者: Price (Price)
# 時間:  5/16
# 標題: [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 作者: Frankaze (神采風華)
# 時間:  5/16
# 標題: [轉錄]再轉一篇好文來
# 作者: Frankaze (神采風華)
# 時間:  5/16
# 標題: [轉錄][情報] 夏洛特山貓系列
# 作者: Price (Price)
# 時間:  5/16
# 標題: [轉錄]Re: [心得] 真是受不了糗爺....
# 作者: Price (Price)
# 時間:  5/16
# 標題: [轉錄]總冠軍賽NO.2觀後感
# 作者: Price (Price)
# 時間:  5/16
# 標題: [心得] Rasheed Wallace
# 作者: AmuroNamie (原來太嗨真的會失眠^___^)
# 時間:  5/16
# 標題: 掌控球賽的男人
# 作者: toptree (  )
# 時間:  5/16
# 標題: [閒聊] 說說2004季後賽名場面回顧
# 作者: skchang (3EB板開板囉！)
# 時間:  5/16
# 標題: [心得] 其實說穿了 就是活塞的防守太可怕了
# 作者: shineup ()
# 時間:  5/16
# 標題: Re: [閒聊] 說說2004季後賽名場面回顧
# 作者: cOvi (喵~)
# 時間:  5/16
# 標題: Re: [閒聊] 說說2004季後賽名場面回顧
# 作者: ykshih (￼N￼Ns)
# 時間:  5/16
# 標題: Re: [閒聊] 說說2004季後賽名場面回顧
# 作者: Frankaze (神采風華)
# 時間:  5/16
# 標題: [轉錄]Re: 總冠軍賽NO.3觀後感
# 作者: Price (Price)
# 時間:  5/16
# 標題: [轉錄]Re: 總冠軍賽NO.3觀後感
# 作者: Frankaze (神采風華)
# 時間:  5/16
# 標題: Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 作者: star1 (第一次魔術表演不算成功)
# 時間:  5/16
# 標題: Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 作者: coldspring (笑笑)
# 時間:  5/16
# 標題: Re: Kobe is frustrated...
# 作者: airbear (地圖)
# 時間:  5/16
# 標題: Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 作者: pennykidd (andre)
# 時間:  5/16

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
page = '' #抓最新文章
board = 'refresh' #版名：充電板
url = 'https://www.ptt.cc/bbs/'+ board +'/index'+str(page)+'.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print('標題: ' + d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find(class_='article-meta-value').text)
        print('時間: ' + soup.find(class_='date').text)
    except:
        continue
# Out:
# 標題: [南區] 12/26(四)OKR目標管理入門講座
# 作者: startuptalk (創業台槓)
# 時間: 12/04
# 標題: [南區] 1/04(六)[email protected] 2.0社交經營Chatbot教戰班
# 作者: JedLin (汪汪)
# 時間: 12/04
# 標題: [南區] 1/12(日)政府採購案招投標實戰
# 作者: startuptalk (創業台槓)
# 時間: 12/04
# 標題: [北區] 咖啡閒談-品嚐咖啡的酸度閒談人生的濃度
# 作者: roysu619 (Piii)
# 時間: 12/04
# 標題: [南區] 1/05(日)讓記者想報導的品牌故事撰寫入門
# 作者: JedLin (汪汪)
# 時間: 12/04
# 標題: [北區] 教你如何擁有終身俸的被動收入
# 作者: hero0323 (參見英雄)
# 時間: 12/04
# 標題: ★★★ ２４小時學會【日文閱讀翻譯】免基礎！
# 作者: Y120372767 (往事渾如夢)
# 時間: 12/04
# 標題: [南區] 1/5(日)零基礎UI/UX設計入門
# 作者: startuptalk (創業台槓)
# 時間: 12/04
# 標題: [台北]4小時一次搞定[email protected]及FB粉專經營
# 作者: namchu (艾瑞克)
# 時間: 12/04
# 標題: [南區] 1/18(六)GA網站行銷分析入門班
# 作者: JedLin (汪汪)
# 時間: 12/04
# 標題: [情報]玩轉excel vba線上課程~~年度優惠中
# 作者: x38517489 (燒肉飯)
# 時間: 12/04
# 標題: [南區] 1/23(日)感動顧客變鐵粉的服務經營教戰班
# 作者: JedLin (汪汪)
# 時間: 12/04
# 標題: [台北] 12/15(日)情緒如何影響你的生活-情緒心理
# 作者: closeme2018 (親密引力)
# 時間: 12/04
# 標題: [台北] 12/21(六) 關係好朋友-關係學習分享會
# 作者: closeme2018 (親密引力)
# 時間: 12/04
# 標題: [南區] 1/15(三)高效益網紅影響力行銷術
# 作者: startuptalk (創業台槓)
# 時間: 12/04
# 標題: [全省] 2020台電招考700人 最新考情講座
# 作者: nancylee51 (nancylee51)
# 時間: 12/04
# 標題: [北區] 中山社大超值的寒期班課程6堂1000元!
# 作者: yw2017 (小資女)
# 時間: 12/04
# 標題: [北區] 風水卜卦戰鬥營 #1/18台北起跑
# 作者: st21982 ()
# 時間: 12/04
# 標題: [新北]兒童權利公約公益講座~ 兒童權利知多少B場
# 作者: GIOKID (噹噹噹就是only you)
# 時間: 12/04
# 標題: [公告] 充電版2010版規
# 作者: AMYHUANG (原來如此)
# 時間: 12/04
# 標題: Fw: [公告] 反智財局恣意封網聯署
# 作者: AMYHUANG (原來如此)
# 時間: 12/04
# 標題: Re: [全省]免費講座擴充記憶體五的立體次方提升智商
# 作者: qweqq (qweqq)
# 時間: 12/04
