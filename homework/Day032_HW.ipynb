# %% [markdown]
# # 反爬：驗證碼處理
#
# * 了解「驗證碼機制」的反爬蟲機制
# * 「驗證碼機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 讀讀看「test」資料夾下的圖檔！
# * 像 test/test2.png 這種複雜的圖片怎麼辦？

# %% [markdown]
# ### 讀讀看「test」資料夾下的圖檔！

# %%
import requests
import pytesseract
from PIL import Image
from io import BytesIO

# %%
response = requests.get('https://i0.wp.com/www.embhack.com/wp-content/uploads/2018/06/hello-world.png')
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=640x377 at 0x12295C6D8>

# %% [markdown]
# ### 像 test/test2.png 這種複雜的圖片怎麼辦？

# %%
#使用RGBA彩色辨識
img = Image.open("test/test2.png").convert("RGBA")
img
# Out:
# <PIL.Image.Image image mode=RGBA size=154x64 at 0x1232F0E80>

# %%
code = pytesseract.image_to_string(img)
print(code)
# Out:
# 1413
