# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10352

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# [{'area_id': 28, 'title': '台北市', 'priority': 150, 'ts_update': 1547519309}, {'area_id': 16, 'title': '桃園', 'priority': 140, 'ts_update': 1547452573}, {'area_id': 2, 'title': '台中', 'priority': 125, 'ts_update': 1547507368}, {'area_id': 17, 'title': '高雄', 'priority': 95, 'ts_update': 1547507403}]
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 高雄, 代號(area_id): 17

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 十二月 12
# 十二月 13
# 十二月 14
# 十二月 15
# 十二月 16

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2019-12-12"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
# html = soup.find_all("li")
print(html)
# Out:
# <div class="pc-movie-schedule-form">
#     <div class="area_timebox">
#    <div class="area_title">台北市</div>
#       <ul id="theater_id_38" class="area_time _c jq_area_time" data-theater_name="台北樂聲影城" data-theater_url="http://www.luxcinema.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=38" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=38">台北樂聲影城</a>
#            <span>02-23118628</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="72558125" class="gabtn"
#                         value="2019-12-12 19:10:00"  data-movie="f6db052536734576a3937942e8b55a10"
#                         data-cinema="46efa950eafa11e38b12987bdb90dba4" data-session="af417007cc3743828dc942d92d399478"
#                         data-date="1576080000" data-time="1576149000"
#                         data-movie_type="數位"
#                         data-movie_title="一屍到底番外篇：好萊塢大作戰！"
#                         data-movie_date="12.12"
#                         data-movie_time="19:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-ezding="ezding"
#                         />
#                     <label for="72558125" class="">19:10</label>
#                                                                                     <input type="radio" name="schedule_list" id="72558126" class="gabtn"
#                         value="2019-12-12 22:40:00"  data-movie="f6db052536734576a3937942e8b55a10"
#                         data-cinema="46efa950eafa11e38b12987bdb90dba4" data-session="ca37eeace75047549962272d3646ffca"
#                         data-date="1576080000" data-time="1576161600"
#                         data-movie_type="數位"
#                         data-movie_title="一屍到底番外篇：好萊塢大作戰！"
#                         data-movie_date="12.12"
#                         data-movie_time="22:40"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-ezding="ezding"
#                         />
#                     <label for="72558126" class="">22:40</label>
#                                                                                     <input type="radio" name="schedule_list" id="72558127" class="gabtn"
#                         value="2019-12-13 01:35:00"  data-movie="f6db052536734576a3937942e8b55a10"
#                         data-cinema="46efa950eafa11e38b12987bdb90dba4" data-session="4d4898a9fcad49e1b68f55ad0655cfae"
#                         data-date="1576080000" data-time="1576172100"
#                         data-movie_type="數位"
#                         data-movie_title="一屍到底番外篇：好萊塢大作戰！"
#                         data-movie_date="12.13"
#                         data-movie_time="01:35"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-ezding="ezding"
#                         />
#                     <label for="72558127" class="select">01:35</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_42" class="area_time _c jq_area_time" data-theater_name="喜滿客絕色影城" data-theater_url="http://www.cinema7.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=42" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=42">喜滿客絕色影城</a>
#            <span>02-23811339</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="72561708" class="gabtn"
#                         value="2019-12-13 00:20:00"  data-movie="d3bce4f2709d4c57a00ebc33c8df1031"
#                         data-cinema="40288eb0050f542401050f55532606b5" data-session="897b169e2fad400280726d51da4ac0a7"
#                         data-date="1576080000" data-time="1576167600"
#                         data-movie_type="數位"
#                         data-movie_title="一屍到底番外篇：好萊塢大作戰！"
#                         data-movie_date="12.13"
#                         data-movie_time="00:20"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-ezding="ezding"
#                         />
#                     <label for="72561708" class="select">00:20</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_45" class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_url="http://www.vscinemas.com.tw/" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">台北信義威秀影城</a>
#            <span>02-87805566</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="72539078" class="gabtn"
#                         value="2019-12-12 18:30:00"  data-movie="9154935e03f54e8092a78f7b665b7cc6"
#                         data-cinema="40288eb0050f542401050f554e7e0674" data-session="4d5c11f861e74dce8a6743cca1239c00"
#                         data-date="1576080000" data-time="1576146600"
#                         data-movie_type="數位"
#                         data-movie_title="一屍到底番外篇：好萊塢大作戰！"
#                         data-movie_date="12.12"
#                         data-movie_time="18:30"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-ezding="ezding"
#                         />
#                     <label for="72539078" class="">18:30</label>
#                                                </div>
#            </li>
#           </ul>
#       <ul id="theater_id_186" class="area_time _c jq_area_time" data-theater_name="喜樂時代影城南港店" data-theater_url="http://www.centuryasia.com.tw/default.aspx" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=186" >
#        <li class="adds">
#            <a href="https://movies.yahoo.com.tw/theater_result.html/id=186">喜樂時代影城南港店</a>
#            <span>02-27888185</span>
#        </li>
#                          <li class="taps">
#                 <span class="tapR">數位</span>                           </li>
#            <li class="time _c">
#                <div class="input_picker jq_input_picker">
#                                                                    <input type="radio" name="schedule_list" id="72538809" class="gabtn"
#                         value="2019-12-12 21:10:00"  data-movie="3c811ad20b484d17be9a6ad2a09df339"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="21781be4cfda46a0a91a4808a50beab1"
#                         data-date="1576080000" data-time="1576156200"
#                         data-movie_type="數位"
#                         data-movie_title="一屍到底番外篇：好萊塢大作戰！"
#                         data-movie_date="12.12"
#                         data-movie_time="21:10"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-ezding="ezding"
#                         />
#                     <label for="72538809" class="">21:10</label>
#                                                                                     <input type="radio" name="schedule_list" id="72538810" class="gabtn"
#                         value="2019-12-12 22:25:00"  data-movie="3c811ad20b484d17be9a6ad2a09df339"
#                         data-cinema="40288eb0050f542401050f5681782dc5" data-session="212bd5553d574f4bb9333fc03d5187e7"
#                         data-date="1576080000" data-time="1576160700"
#                         data-movie_type="數位"
#                         data-movie_title="一屍到底番外篇：好萊塢大作戰！"
#                         data-movie_date="12.12"
#                         data-movie_time="22:25"
#                         data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-ezding="ezding"
#                         />
#                     <label for="72538810" class="">22:25</label>
#                                                </div>
#            </li>
#           </ul>
#    </div>
#
#     <div class="booking_modal jq_booking_modal">
#     <div class="booking_modal_backdrop"></div>
#     <!-- 時報訂票 ＆ 有官網訂票 新增 class => no_seats -->
#     <div class="booking_modal_content jq_booking_modal_content">
#         <form method="get" action="https://movies.yahoo.com.tw/ticket/ezding_ticket" target="_blank" id="form_schedule">
#                 <div class="ezding_ticket_value">
#             <input type="hidden" name="movie_id" value="">
#             <input type="hidden" name="cinema_id" value="">
#             <input type="hidden" name="session_id" value="">
#             <input type="hidden" name="date" value="">
#             <input type="hidden" name="time" value="">
#             <input type="hidden" name="campaign_code" value="yahoopc">
#         </div>
#         <ul class="top_infos">
#             <li>
#                 <p>片名</p>
#                 <h3 id="top_infos_movie"></h3>
#             </li>
#             <li>
#                 <p>影城</p>
#                 <h3 id="top_infos_theater"></h3>
#             </li>
#             <li>
#                 <p>日期</p>
#                 <h3 id="top_infos_date"></h3>
#             </li>
#             <li>
#                 <p>版本</p>
#                 <h3 id="top_infos_movie_type"></h3>
#             </li>
#             <li>
#                 <p>時間</p>
#                 <h3 id="top_infos_time"></h3>
#             </li>
#         </ul>
#
#         <div class="booking_seats">
#             <a href="#" class="theater_schedules gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_全部電影場次', '']">全部電影場次</a>
#             <a href="#" class="theater_url gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_官網訂票', '']" target="_blank">官網訂票</a>
#             <p id="no_theater_url" class="no_theater_url">無提供官網訂票</p>
#
#             <p id="booking_number" class="booking_number">人數</p>
#             <div class="booking_seat_group jq_booking_seat_group">
#                                     <input type="radio" name="tickets" id="seat_1" value="1" />
#                     <label for="seat_1">1</label>
#                                     <input type="radio" name="tickets" id="seat_2" value="2"  checked />
#                     <label for="seat_2">2</label>
#                                     <input type="radio" name="tickets" id="seat_3" value="3" />
#                     <label for="seat_3">3</label>
#                                     <input type="radio" name="tickets" id="seat_4" value="4" />
#                     <label for="seat_4">4</label>
#                                     <input type="radio" name="tickets" id="seat_5" value="5" />
#                     <label for="seat_5">5</label>
#                                     <input type="radio" name="tickets" id="seat_6" value="6" />
#                     <label for="seat_6">6</label>
#                             </div>
#             <button type="submit" class="action_btn action_booking_btn jq_booking_btn gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_選位', '']">選位</button>
#             <a href="#" class="action_btn action_link jq_booking_link gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_時報戲院_官網選位', '']" target="_blank">官網訂票</a>
#             <button type="button" class="action_btn close jq_close_booking_btn">關閉</button>
#         </div>
#         </form>
#
#         <!-- 無官網訂票區塊 -->
#         <div class="no_theater_section">
#             <p>無提供官網訂票</p>
#             <button type="button" class="action_btn close jq_close_booking_btn">關閉</button>
#         </div>
#     </div>
# </div></div>
# [<ul class="area_time _c jq_area_time" data-theater_name="台北樂聲影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=38" data-theater_url="http://www.luxcinema.com.tw/" id="theater_id_38">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=38">台北樂聲影城</a>
# <span>02-23118628</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="46efa950eafa11e38b12987bdb90dba4" data-date="1576080000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-movie="f6db052536734576a3937942e8b55a10" data-movie_date="12.12" data-movie_time="19:10" data-movie_title="一屍到底番外篇：好萊塢大作戰！" data-movie_type="數位" data-session="af417007cc3743828dc942d92d399478" data-time="1576149000" id="72558125" name="schedule_list" type="radio" value="2019-12-12 19:10:00"/>
# <label class="" for="72558125">19:10</label>
# <input class="gabtn" data-cinema="46efa950eafa11e38b12987bdb90dba4" data-date="1576080000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-movie="f6db052536734576a3937942e8b55a10" data-movie_date="12.12" data-movie_time="22:40" data-movie_title="一屍到底番外篇：好萊塢大作戰！" data-movie_type="數位" data-session="ca37eeace75047549962272d3646ffca" data-time="1576161600" id="72558126" name="schedule_list" type="radio" value="2019-12-12 22:40:00"/>
# <label class="" for="72558126">22:40</label>
# <input class="gabtn" data-cinema="46efa950eafa11e38b12987bdb90dba4" data-date="1576080000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-movie="f6db052536734576a3937942e8b55a10" data-movie_date="12.13" data-movie_time="01:35" data-movie_title="一屍到底番外篇：好萊塢大作戰！" data-movie_type="數位" data-session="4d4898a9fcad49e1b68f55ad0655cfae" data-time="1576172100" id="72558127" name="schedule_list" type="radio" value="2019-12-13 01:35:00"/>
# <label class="select" for="72558127">01:35</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="喜滿客絕色影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=42" data-theater_url="http://www.cinema7.com.tw/" id="theater_id_42">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=42">喜滿客絕色影城</a>
# <span>02-23811339</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="40288eb0050f542401050f55532606b5" data-date="1576080000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-movie="d3bce4f2709d4c57a00ebc33c8df1031" data-movie_date="12.13" data-movie_time="00:20" data-movie_title="一屍到底番外篇：好萊塢大作戰！" data-movie_type="數位" data-session="897b169e2fad400280726d51da4ac0a7" data-time="1576167600" id="72561708" name="schedule_list" type="radio" value="2019-12-13 00:20:00"/>
# <label class="select" for="72561708">00:20</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_45">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">台北信義威秀影城</a>
# <span>02-87805566</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1576080000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-movie="9154935e03f54e8092a78f7b665b7cc6" data-movie_date="12.12" data-movie_time="18:30" data-movie_title="一屍到底番外篇：好萊塢大作戰！" data-movie_type="數位" data-session="4d5c11f861e74dce8a6743cca1239c00" data-time="1576146600" id="72539078" name="schedule_list" type="radio" value="2019-12-12 18:30:00"/>
# <label class="" for="72539078">18:30</label>
# </div>
# </li>
# </ul>, <ul class="area_time _c jq_area_time" data-theater_name="喜樂時代影城南港店" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=186" data-theater_url="http://www.centuryasia.com.tw/default.aspx" id="theater_id_186">
# <li class="adds">
# <a href="https://movies.yahoo.com.tw/theater_result.html/id=186">喜樂時代影城南港店</a>
# <span>02-27888185</span>
# </li>
# <li class="taps">
# <span class="tapR">數位</span> </li>
# <li class="time _c">
# <div class="input_picker jq_input_picker">
# <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1576080000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-movie="3c811ad20b484d17be9a6ad2a09df339" data-movie_date="12.12" data-movie_time="21:10" data-movie_title="一屍到底番外篇：好萊塢大作戰！" data-movie_type="數位" data-session="21781be4cfda46a0a91a4808a50beab1" data-time="1576156200" id="72538809" name="schedule_list" type="radio" value="2019-12-12 21:10:00"/>
# <label class="" for="72538809">21:10</label>
# <input class="gabtn" data-cinema="40288eb0050f542401050f5681782dc5" data-date="1576080000" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '一屍到底番外篇：好萊塢大作戰！']" data-movie="3c811ad20b484d17be9a6ad2a09df339" data-movie_date="12.12" data-movie_time="22:25" data-movie_title="一屍到底番外篇：好萊塢大作戰！" data-movie_type="數位" data-session="212bd5553d574f4bb9333fc03d5187e7" data-time="1576160700" id="72538810" name="schedule_list" type="radio" value="2019-12-12 22:25:00"/>
# <label class="" for="72538810">22:25</label>
# </div>
# </li>
# </ul>]

# %%
title = html[i].find("input",{'name':'schedule_list'}).attrs["data-movie_title"]
print("影片名稱： " + title + "\n\n")
for i in range(len(html)):
    theater = html[i].attrs["data-theater_name"]
    mtype = html[i].find("input",{'name':'schedule_list'}).attrs["data-movie_type"]
    date = html[i].find("input",{'name':'schedule_list'}).attrs["data-movie_date"]
    time = html[i].find("input",{'name':'schedule_list'}).attrs["data-movie_time"]
    print("電影院： " + theater)
    print("影片類型： " + mtype)
    print("放映日期時間： " + date + " " + time+ "\n")
# Out:
# 影片名稱： 一屍到底番外篇：好萊塢大作戰！
#
#
# 電影院： 台北樂聲影城
# 影片類型： 數位
# 放映日期時間： 12.12 19:10
#
# 電影院： 喜滿客絕色影城
# 影片類型： 數位
# 放映日期時間： 12.13 00:20
#
# 電影院： 台北信義威秀影城
# 影片類型： 數位
# 放映日期時間： 12.12 18:30
#
# 電影院： 喜樂時代影城南港店
# 影片類型： 數位
# 放映日期時間： 12.12 21:10
